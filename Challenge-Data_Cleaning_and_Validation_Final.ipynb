# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
# %matplotlib inline

# %% [markdown]
# ## Challenge
#
# Determind the five most commone journals and the total articles for each. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal.

# %%
# upload the data file that contains the dirty data
dirty = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv',encoding='"ISO-8859-1"')
dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# PMID/PMCID                                             1928 non-null object
# Publisher                                              2127 non-null object
# Journal title                                          2126 non-null object
# Article title                                          2127 non-null object
# COST (£) charged to Wellcome (inc VAT when charged)    2127 non-null object
# dtypes: object(5)
# memory usage: 41.6+ KB

# %%
df = dirty.copy()
df = df.rename(columns={'PMID/PMCID':'ID', 'Publisher':'Publisher', 'Journal title':'Journal', 'Article title':'Article',
                        'COST (£) charged to Wellcome (inc VAT when charged)':'Cost'})
df.head()
# Out:
#                       ID Publisher                 Journal  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                              Article      Cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# ID           1928 non-null object
# Publisher    2127 non-null object
# Journal      2126 non-null object
# Article      2127 non-null object
# Cost         2127 non-null object
# dtypes: object(5)
# memory usage: 41.6+ KB

# %%
# removing null values in Journal column
df=df[df['Journal'].notnull()][['ID', 'Publisher', 'Journal', 'Article', 'Cost']]

# %%
# Look at unique journal names
df['Journal'].value_counts()
# Out:
# PLoS One                                                    92
# PLoS ONE                                                    62
# Journal of Biological Chemistry                             48
# Nucleic Acids Research                                      21
# Proceedings of the National Academy of Sciences             19
# PLoS Neglected Tropical Diseases                            18
# Human Molecular Genetics                                    18
# Nature Communications                                       17
# PLoS Pathogens                                              15
# Neuroimage                                                  15
# PLoS Genetics                                               15
# NeuroImage                                                  14
# PLOS ONE                                                    14
# BMC Public Health                                           14
# Brain                                                       14
# Movement Disorders                                          13
# Developmental Cell                                          12
# Journal of Neuroscience                                     12
# Biochemical Journal                                         12
# Journal of General Virology                                 11
# Current Biology                                             10
# BMJ                                                         10
# PLOS One                                                    10
# Neuron                                                       9
# Cell Reports                                                 9
# Hepatology                                                   8
# Journal of Virology                                          8
# Journal of Clinical Endocrinology and Metabolism             8
# Development                                                  8
# Malaria Journal                                              8
#                                                             ..
# Journal of Chemical Information and Modeling                 1
# Journal of Cerebral Blood Flow and Metabolism                1
# American Journal of Medical Genetics                         1
# Journal of Parasitology Research                             1
# Sexually Transmitted Infections                              1
# Journal of Consulting and Clinical Psychology                1
# Plos                                                         1
# CHILD: Care, Heath & Development                             1
# Journal of Virological Methods                               1
# Heptology                                                    1
# Psychological Review                                         1
# Molecular Membrane Biology                                   1
# PLOS NTD                                                     1
# Trends in Neuroscience                                       1
# Journal of Medicinal Chemistry                               1
# Methods in Molecular Biology                                 1
# Human Brain Mapping                                          1
# Math Biosci                                                  1
# Journal of Endocrinology                                     1
# Influenza Other Respi Viruses.                               1
# BMC Genetics                                                 1
# Nitric Oxide                                                 1
# Reproductive Sciences                                        1
# Aging Cell                                                   1
# Int J Epidemiol                                              1
# American Journal of Geriatric Psychiatry                     1
# Journal of Cognitive Neuroscience                            1
# Analytical Biochemistry                                      1
# Autophagy                                                    1
# Centaurus                                                    1
# Name: Journal, Length: 984, dtype: int64

# %% [markdown]
# ## Cleaning dirty Journal column
#
# 1. Strip Whitespace
# 2. Convert to upper case
# 3. Remove misc. characters.
# 4. Spell Check

# %%
# Strip whitespace
df['clean_journal'] = df['Journal'].str.strip()

# convert to upper case
df['clean_journal'] = df['Journal'].str.upper()

df['clean_journal'].value_counts()
# Out:
# PLOS ONE                                            190
# JOURNAL OF BIOLOGICAL CHEMISTRY                      53
# NEUROIMAGE                                           29
# PLOS PATHOGENS                                       24
# PLOS GENETICS                                        24
# NUCLEIC ACIDS RESEARCH                               23
# PLOS NEGLECTED TROPICAL DISEASES                     20
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES      20
# NATURE COMMUNICATIONS                                19
# HUMAN MOLECULAR GENETICS                             19
# BMC PUBLIC HEALTH                                    14
# BRAIN                                                14
# MOVEMENT DISORDERS                                   13
# JOURNAL OF NEUROSCIENCE                              12
# DEVELOPMENTAL CELL                                   12
# BIOCHEMICAL JOURNAL                                  12
# JOURNAL OF GENERAL VIROLOGY                          11
# CURRENT BIOLOGY                                      11
# BMJ                                                  10
# PLOSONE                                               9
# BMJ OPEN                                              9
# NEURON                                                9
# CELL REPORTS                                          9
# PLOS COMPUTATIONAL BIOLOGY                            9
# JOURNAL OF STRUCTURAL BIOLOGY                         8
# JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM      8
# JOURNAL OF CELL SCIENCE                               8
# EUROPEAN JOURNAL OF IMMUNOLOGY                        8
# MOLECULAR MICROBIOLOGY                                8
# MALARIA JOURNAL                                       8
#                                                    ...
# JOURNAL OF MEDICAL VIROLOGY                           1
# ACS CHEMICAL NEUROSCIENCE                             1
# NEUROBIOLOGY OF DISEASE                               1
# NEURODEGENERATIVE DISEASES                            1
# OPHTHALMOLOGY                                         1
# MOLECULAR AND CELLULAR PROTEOMICS                     1
# AMERICAN JOURNAL OF MEDICAL GENETICS PART A           1
# INTERNATIONAL PSYCHOGERIATRICS                        1
# CHEMISTRY -  EUROPEAN JOURNAL                         1
# FUNGAL BIOLOGY                                        1
# TRENDS IN NEUROSCIENCE                                1
# CHANNELS                                              1
# REPRODUCTION(CAMBRIDGE, ENGLAND)                      1
# AMERICAN SOCIETY FOR NUTRITION                        1
# CHEMICAL COMMUNICATION                                1
# IMMUNOLOGICAL REVIEWS                                 1
# CLINICAL AND EXPERIMENTAL ALLERGY                     1
# JOURNAL OF EPIDEMIOLOGY & COMMUNITY HEALTH            1
# NEPHROLOGY DIALYSIS TRANSPLANTATION                   1
# PROTEIN EXPR PURIF.                                   1
# JOURNAL OF SMALL ANIMAL PRACTICE                      1
# PARASIT VECTORS.                                      1
# PROC NATL ACAD SCI U S A.                             1
# NITRIC OXIDE                                          1
# AUTOPHAGY                                             1
# BRITISH JOUNAL OF PHARMACOLOGY                        1
# CELL AND TISSUE RESEARCH                              1
# INTERNATIONAL JOURNAL OF DEVELOPMENTAL BIOLOGY        1
# EUROPEAN JOURNAL OF ENGLISH STUDIES                   1
# MATERNAL AND CHILD NUTRITION                          1
# Name: clean_journal, Length: 928, dtype: int64

# %% [markdown]
# From this it is clear that some of the journals, for example, "PLOS ONE", have been cleaned.

# %%
def is_a_string(x):
    return not str(x).isalnum()

#print(df.clean_journal.apply(is_a_string))
print('Filtering the whole series:')
print(list(filter(lambda x: str(x).isalnum(), df.clean_journal)))

print('\nApplying filter() to each value in the series:')
print(df.clean_journal.apply(lambda x: ''.join(list(filter(str.isalnum, str(x))))))
# Out:
# Filtering the whole series:
# ['BIOMACROMOLECULES', 'BIOCHEMISTRY', 'GASTROENTEROLOGY', 'CHEST', 'EMOTION', 'MBIO', 'BLOOD', 'BLOOD', 'BLOOD', 'BLOOD', 'BLOOD', 'BLOOD', 'BLOOD', 'EVODEVO', 'TRIALS', 'TRIALS', 'TRIALS', 'TRIALS', 'BJOPHTHALMOL', 'BMJ', 'BMJ', 'BMJ', 'BMJ', 'GUT', 'BMJ', 'GUT', 'GUT', 'HEART', 'THORAX', 'THORAX', 'BMJ', 'BMJ', 'BMJ', 'BMJ', 'BMJ', 'MBIO', 'PARASITOLOGY', 'PARASITOLOGY', 'PARASITOLOGY', 'PARASITOLOGY', 'PARASITOLOGY', 'PARASITOLOGY', 'RNA', 'RNA', 'DEVELOPMENT', 'DEVELOPMENT', 'DEVELOPMENT', 'DEVELOPMENT', 'DEVELOPMENT', 'DEVELOPMENT', 'DEVELOPMENT', 'GENETICS', 'PNAS', 'NEUROIMAGE', 'NEUROIMAGE', 'ATHEROSCLEROSIS', 'ATHEROSCLEROSIS', 'BIOCHIMIE', 'BIOMATERIALS', 'BIOMATERIALS', 'BIOSYSTEMS', 'BONE', 'BONE', 'BONE', 'CELL', 'CELL', 'CELL', 'CELL', 'CELL', 'COGNITION', 'CORTEX', 'CORTEX', 'CORTEX', 'CORTEX', 'CORTEX', 'ELSEVIER', 'ELSEVIER', 'ELSEVIER', 'ELSEVIER', 'ELSEVIER', 'ELSEVIER', 'ELSEVIER', 'ENDEAVOUR', 'ENDEAVOUR', 'GASTROENTEROLOGY', 'GENE', 'GENE', 'GENE', 'IMMNUNOBIOLOGY', 'IMMUNITY', 'IMMUNITY', 'LANCET', 'MATURITAS', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROIMAGE', 'NEUROLMAGE', 'NEUROLMAGE', 'NEURON', 'NEURON', 'NEURON', 'NEURON', 'NEURON', 'NEURON', 'NEURON', 'NEUROPHARMACOLOGY', 'NEUROPHARMACOLOGY', 'NEUROPHYSIOLOGIA', 'NEUROPSYCHOLOGIA', 'NEUROPSYCHOLOGIA', 'NEUROPSYCHOLOGIA', 'NEUROPSYCHOLOGIA', 'NEUROPSYCHOLOGIA', 'NEUROPSYCHOLOGIA', 'NEUROPSYCHOLOGIA', 'NEUROSCIENCE', 'NEUROSCIENCE', 'OPHTHALMOLOGY', 'PAIN', 'PAIN', 'PAIN', 'PAIN', 'PARSITOLOGY', 'PROTIST', 'SEIZURE', 'STRUCTURE', 'STRUCTURE', 'STRUCTURE', 'STRUCTURE', 'STRUCTURE', 'STRUCTURE', 'TUBERCULOSIS', 'TUBERCULOSIS', 'VACCINE', 'VACCINE', 'VACCINE', 'VACCINE', 'VIROLOGY', 'NEURON', 'NEURON', 'STRUCTURE', 'VACCINE', 'ENDOCRINOLOGY', 'ENDOCRINOLOGY', 'HAEMATOLOGICA', 'ONCOTARGET', 'ONCOTARGET', 'NANOTECHNOLOGY', 'NANOTECHNOLOGY', 'IJTLD', 'THERANOSTICS', 'BIOPOLYMERS', 'TRAFFIC', 'HEPTOLOGY', 'NEUROEPIDEMIOLOGY', 'NEUROPSYCHOBIOLOGY', 'RESPIRATION', 'AUTOPHAGY', 'CHANNELS', 'EPIGENETICS', 'EPIGENETICS', 'EPIGENTICS', 'EPIGENTICS', 'NEUROLOGY', 'JERPH', 'SENSORS', 'PNAS', 'PNAS', 'PNAS', 'BIOSOCIETIES', 'FRONTIERS', 'LEUKEMIA', 'EMBO', 'LEUKEMIA', 'NEUROPSYCHOPHARMACOLOGY', 'NEUROPSYCHOPHARMACOLOGY', 'NEUROPSYCHOPHARMACOLOGY', 'NEUROPSYCHOPHARMACOLOGY', 'NEUROPSYCHOPHARMACOLOGY', 'ONCOGENE', 'ONCOGENE', 'ONCOGENE', 'BRAIN', 'BRAIN', 'BRAIN', 'BRAIN', 'BRAIN', 'BRAIN', 'BRAIN', 'BRAIN', 'BRAIN', 'RHEUMATOLOGY', 'RHEUMATOLOGY', 'BRAIN', 'GLYCOBIOLOGY', 'BIINFORMATICS', 'BIOINFORMATICS', 'BIOINFORMATICS', 'BIOINFORMATICS', 'BIOINFORMATICS', 'BRAIN', 'BRAIN', 'BRAIN', 'BRAIN', 'DATABASE', 'GLYCOBIOLOGY', 'BIOSOCIETIES', 'PNAS', 'PNAS', 'BIOLOGY', 'PLOS', 'PLOS', 'PLOS', 'PLOS', 'PLOSONE', 'PLOSONE', 'PLOSONE', 'PLOSONE', 'PLOSONE', 'PLOSONE', 'PLOSONE', 'PLOSONE', 'PLOSONE', 'PNTD', 'CORTEX', 'INTERFACE', 'NEUROSCIENTIST', 'MICROBIOLOGY', 'MICROBIOLOGY', 'MICROBIOLOGY', 'BIOGERONTOLOGY', 'DIABETOLOGIA', 'DIABETOLOGIA', 'DIABETOLOGIA', 'HERNIA', 'IMMUNOGENETICS', 'IMMUNOGENETICS', 'METABOLOMICS', 'NEUROGENETICS', 'NEUROINFORMATICS', 'PSYCHOPHARMACOLOGY', 'PSYCHOPHARMACOLOGY', 'PSYCHOPHARMACOLOGY', 'SPRINGER', 'UROLITHIASIS', 'AGE', 'AGE', 'PEDIATRICS', 'VIROLOGY', 'DEVELOPMENT', 'ENDOCRINOLOGY', 'ENDOCRINOLOGY', 'ENDOCRINOLOGY', 'ENDOCRINOLOGY', 'BJP', 'ADDICTION', 'ADDICTION', 'BIOETHICS', 'BIOETHICS', 'BIOETHICS', 'BIOPOLYMERS', 'CHEMBIOCHEM', 'CHEMBIOCHEM', 'CHEMBIOCHEM', 'CYTOSKELETON', 'EPILEPSIA', 'EVOLUTION', 'EVOLUTION', 'GLIA', 'GLIA', 'HEPATOLOGY', 'HEPATOLOGY', 'HEPATOLOGY', 'HEPATOLOGY', 'HEPATOLOGY', 'HIPPOCAMPUS', 'HIPPOCAMPUS', 'HIPPOCAMPUS', 'TRAFFIC', 'BIOETHICS', 'HEPATOLOGY', 'TRAFFIC', 'TRAFFIC', 'EPILEPSIA',  ...
#
# Applying filter() to each value in the series:
# 0                                 PSYCHOLOGICALMEDICINE
# 1                                     BIOMACROMOLECULES
# 2                                              JMEDCHEM
# 3                                              JMEDCHEM
# 4                                              JORGCHEM
# 5                           JOURNALOFMEDICINALCHEMISTRY
# 6                             JOURNALOFPROTEOMERESEARCH
# 7                                              MOLPHARM
# 8                                    ACSCHEMICALBIOLOGY
# 9                                    ACSCHEMICALBIOLOGY
# 10              JOURNALOFCHEMICALINFORMATIONANDMODELING
# 11                          JOURNALOFMEDICINALCHEMISTRY
# 12                          JOURNALOFMEDICINALCHEMISTRY
# 13                                         BIOCHEMISTRY
# 14                          JOURNALOFMEDICINALCHEMISTRY
# 15                                     GASTROENTEROLOGY
# 16                         JOURNALOFBIOLOGICALCHEMISTRY
# 17                                  JOURNALOFIMMUNOLOGY
# 18                                  JOURNALOFIMMUNOLOGY
# 19                                   ACSCHEMICALBIOLOGY
# 20                                   ACSCHEMICALBIOLOGY
# 21                                   ACSCHEMICALBIOLOGY
# 22                              ACSCHEMICALNEUROSCIENCE
# 23                                              ACSNANO
# 24                              AMERICANCHEMICALSOCIETY
# 25                                  ANALYTICALCHEMISTRY
# 26                                  ANALYTICALCHEMISTRY
# 27                                  ANALYTICALCHEMISTRY
# 28                                BIOCONJUGATECHEMISTRY
# 29                          JOURNALOFMEDICINALCHEMISTRY
#                              ...
# 2097                              MOLECULARMICROBIOLOGY
# 2098                                     OBESITYREVIEWS
# 2099                                     OBESITYREVIEWS
# 2100                               STATISTICSINMEDICINE
# 2101                                          STEMCELLS
# 2102                                            SYNAPSE
# 2103                   THEEUROPEANJOURNALOFNEUROSCIENCE
# 2104                                            TRAFFIC
# 2105                                            TRAFFIC
# 2106                            ZOONOSESANDPUBLICHEALTH
# 2107                   AMERICANJOURNALOFTRANSPLANTATION
# 2108                                    ANGEWCHEMSINTED
# 2109                                        CHEMBIOCHEM
# 2110                                        CHEMMEDCHEM
# 2111                                        CHEMMEDCHEM
# 2112                                        CHEMMEDCHEM
# 2113                                          PROTEMICS
# 2114                       JOURNALOFSMALLANIMALPRACTICE
# 2115                                               AIDS
# 2116                                        AIDSJOURNAL
# 2117                                             AIDSUK
# 2118                                             AIDSUK
# 2119    JAIDSJOURNALOFACQUIREDIMMUNEDEFICIENCYSYNDROMES
# 2120     JOURNALOFACQUIREDIMMUNEDEFICIENCYSYNDROMSJAIDS
# 2121                                      JOURNALOFAIDS
# 2122                                CIRCULATIONRESEARCH
# 2123                                               AIDS
# 2124                                  PEDIATRINFECTDISJ
# 2125                                               AIDS
# 2126         JOURNALOFACQUIREDIMMUNEDEFICIENCYSYNDROMES
# Name: clean_journal, Length: 2126, dtype: object

# %%
df['clean_journal'] = df['clean_journal'].str.replace('&', 'AND')
df['clean_journal'] = df['clean_journal'].str.replace('THE ', '')
df['clean_journal'] = df['clean_journal'].str.replace('.', '')
df['clean_journal'] = df['clean_journal'].str.replace('OF ', '')
df['clean_journal'] = df['clean_journal'].str.replace('FOR ', '')
df['clean_journal'] = df['clean_journal'].str.replace(' IN ', ' ')
df['clean_journal'] = df['clean_journal'].str.replace(':', '')
df['clean_journal'] = df['clean_journal'].str.replace(',', '')
df['clean_journal'] = df['clean_journal'].str.replace(' - ', ' ')
df['clean_journal'] = df['clean_journal'].str.replace('  ', ' ')
df['clean_journal'] = df['clean_journal'].str.strip()

# %%
df['clean_journal'].value_counts()
# Out:
# PLOS ONE                                    191
# JOURNAL BIOLOGICAL CHEMISTRY                 61
# NEUROIMAGE                                   29
# NUCLEIC ACIDS RESEARCH                       26
# PLOS GENETICS                                24
# PLOS PATHOGENS                               24
# PROCEEDINGS NATIONAL ACADEMY SCIENCES        22
# PLOS NEGLECTED TROPICAL DISEASES             20
# NATURE COMMUNICATIONS                        19
# HUMAN MOLECULAR GENETICS                     19
# MOVEMENT DISORDERS                           15
# JOURNAL NEUROSCIENCE                         15
# BMC PUBLIC HEALTH                            15
# BRAIN                                        14
# BIOCHEMICAL JOURNAL                          14
# DEVELOPMENTAL CELL                           12
# FASEB JOURNAL                                11
# JOURNAL GENERAL VIROLOGY                     11
# CURRENT BIOLOGY                              11
# PLOS COMPUTATIONAL BIOLOGY                   10
# BMJ                                          10
# MALARIA JOURNAL                              10
# JOURNAL PHYSIOLOGY                            9
# JOURNAL VIROLOGY                              9
# NEURON                                        9
# AMERICAN JOURNAL HUMAN GENETICS               9
# EMBO JOURNAL                                  9
# DEVELOPMENT                                   9
# CELL REPORTS                                  9
# BMJ OPEN                                      9
#                                            ...
# FRONTIERS INTEGRATIVE NEUROSCIENCE            1
# EVALUATION CLINICAL PRACTICE                  1
# EUROPEAN NEUROPSYCHOPHARMACOLOGY              1
# INYERNATIONAL JOURNAL EPIDEMIOLOGY            1
# BMC RESEARCH NOTES                            1
# CLINICAL RADIOLOGY                            1
# CRIMINAL BEHAVIOR AND MENTAL HEALTH           1
# CALCIFIED TISSUE INTERNATIONAL                1
# LEARNING AND INDIVIDUAL DIFFERENCES           1
# NEUROMOLECULAR MEDICINE                       1
# EVOLUTIONARY APPLICATIONS                     1
# CIRCULATION RESEARCH                          1
# RAPID COMMUNICATIONS MASS SPECTROMETRY        1
# PLOS MEDICINE JOURNAL                         1
# INTERNATIONAL JOURNAL MOLECULAR SCIENCES      1
# ACTA DIABETOLOGICA                            1
# METABOLOMICS                                  1
# EUROPEAN JOURNAL PUBLIC HEALTH                1
# IMMUNOLOGY LETTERS                            1
# GENESIS JOURNAL GENETICS                      1
# VIROLOGY JOURNAL                              1
# EXPERT REVIEWS MOLECULAR MEDICINE             1
# ACTA F                                        1
# PEDIATRICS                                    1
# ACS CHEMICAL NEUROSCIENCE                     1
# JOURNAL ABNORMAL PSYCHOLOGY                   1
# NEURODEGENERATIVE DISEASES                    1
# JOURNAL EXPERIMENTAL NANOSCIENCE              1
# EVODEVO                                       1
# BMC MEDICAL ETHICS                            1
# Name: clean_journal, Length: 849, dtype: int64

# %%
df['clean_journal'] = df['clean_journal'].str.replace('AMERICAL','AMERICAN')
df['clean_journal'] = df['clean_journal'].str.replace('ANTIMICOBIAL','ANTIMICROBIAL')
df['clean_journal'] = df['clean_journal'].str.replace('AGFENTS','AGENTS')
df['clean_journal'] = df['clean_journal'].str.replace('BEHAVIOUR', 'BEHAVIOR')
df['clean_journal'] = df['clean_journal'].str.replace('BEHAVIOURAL', 'BEHAVIORAL')
df['clean_journal'] = df['clean_journal'].str.replace('JOURNALS','JOURNAL')
df['clean_journal'] = df['clean_journal'].str.replace('JNL', 'JOURNAL')
df['clean_journal'] = df['clean_journal'].str.replace(' J ',' JOURNAL ')
df['clean_journal'] = df['clean_journal'].str.replace('BIOOHYSICA', 'BIOPHYSICA')
df['clean_journal'] = df['clean_journal'].str.replace('BIOLOGICIAL', 'BIOLOGICAL')
df['clean_journal'] = df['clean_journal'].str.replace('BMS ','BMC ')
df['clean_journal'] = df['clean_journal'].str.replace('BRT', 'BRITISH')
df['clean_journal'] = df['clean_journal'].str.replace('CLINICLA', 'CLINICAL')
df['clean_journal'] = df['clean_journal'].str.replace('CURR BIOL', 'CURRENT BIOLOGY')
df['clean_journal'] = df['clean_journal'].str.replace('EPIGENTICS', 'EPIGENETICS')
df['clean_journal'] = df['clean_journal'].str.replace('PSYCHIATTY', 'PSYCHIATRY')
df['clean_journal'] = df['clean_journal'].str.replace('EPIDEMOLOGY', 'EPIDEMIOLOGY')
df['clean_journal'] = df['clean_journal'].str.replace('HEPTOLOGY', 'HEPATOLOGY')
df['clean_journal'] = df['clean_journal'].str.replace('HUM RESOUR HEALTH', 'HUMAN RESOURCES HEALTH')
df['clean_journal'] = df['clean_journal'].str.replace('IMMNUNOBIOLOGY', 'IMMUNOBIOLOGY')
df['clean_journal'] = df['clean_journal'].str.replace('INT', 'INTERNATIONAL')
df['clean_journal'] = df['clean_journal'].str.replace('INYERNATIONAL', 'INTERNATIONAL')
df['clean_journal'] = df['clean_journal'].str.replace('JOURNAL ACQUIRED IMMUNE DEFICIENCY SYNDROMS (JAIDS)', 
                                                      'JOURNAL ACQUIRED IMMUNE DEFICIENCY SYNDROMES')
df['clean_journal'] = df['clean_journal'].str.replace('JOURNAL AIDS', 'JOURNAL ACQUIRED IMMUNE DEFICIENCY SYNDROMES')
df['clean_journal'] = df['clean_journal'].str.replace('JOURNAL AUTISM AND DEVELOPMENT DISORDERS', 
                                                      'JOURNAL AUTISM AND DEVELOPMENTAL DISORDERS')
df['clean_journal'] = df['clean_journal'].str.replace('BIOL CHEM','BIOLOGICAL CHEMISTRY')
df['clean_journal'] = df['clean_journal'].str.replace('BIOL CHEMISTRY','BIOLOGICAL CHEMISTRY')
df['clean_journal'] = df['clean_journal'].str.replace('J BIOL CHEM','BIOLOGICAL CHEMISTRY')
df['clean_journal'] = df['clean_journal'].str.replace('J BIOL CHEMISTRY','BIOLOGICAL CHEMISTRY')
df['clean_journal'] = df['clean_journal'].str.replace('JOURNAL VISUALIZED EXPERIEMENTS', 'JOURNAL VISUALIZED EXPERIMENTS')
df['clean_journal'] = df['clean_journal'].str.replace('JOURNAL VISULAIZED EXPERMIMENTS', 'JOURNAL VISUALIZED EXPERIMENTS')
df['clean_journal'] = df['clean_journal'].str.replace('MARTEN CHILD NUTR', 'MATERNAL AND CHILD NUTRITION')
df['clean_journal'] = df['clean_journal'].str.replace('MICROBES INFECT', 'MICROBES AND INFECTION')
df['clean_journal'] = df['clean_journal'].str.replace('MOL BIO', 'MOLECULAR BIOLOGY')
df['clean_journal'] = df['clean_journal'].str.replace('NEPHROLOGY DIALYSIS TRANSPLANTATION', 
                                                      'NEPHROLOGY DIALYSIS AND TRANSPLANTATION')
df['clean_journal'] = df['clean_journal'].str.replace('NEUROLMAGE', 'NEUROIMAGE')
df['clean_journal'] = df['clean_journal'].str.replace('NUCLEIC ACID RESEARCH', 'NUCLEIC ACIDS RESEARCH')
df['clean_journal'] = df['clean_journal'].str.replace('PARASIT VECTORS', 'PARASITES AND VECTORS')
df['clean_journal'] = df['clean_journal'].str.replace('PEDIATR', 'PEDIATRIC')
df['clean_journal'] = df['clean_journal'].str.replace('PFLUGERS ARCHIV', 'PFLUGERS ARCHIVE')
df['clean_journal'] = df['clean_journal'].str.replace('PLOSONE','PLOS ONE')
df['clean_journal'] = df['clean_journal'].str.replace('PLOS  ONE','PLOS ONE')
df['clean_journal'] = df['clean_journal'].str.replace('PUBLIC LIBRARY SCIENCE ONE','PLOS ONE')
df['clean_journal'] = df['clean_journal'].str.replace('PUBLIC LIBRARY SCIENCE','PLOS ONE')
df['clean_journal'] = df['clean_journal'].str.replace('PLOS 1','PLOS ONE')
df['clean_journal'] = df['clean_journal'].str.replace('SEX TRANSM INFECT', 'SEXUALLY TRANSMITTED INFECTIONS')
df['clean_journal'] = df['clean_journal'].str.replace('SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOL', 
                                                      'SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOLOGY')
df['clean_journal'] = df['clean_journal'].str.replace('TRENDS NEUROSCIENCE', 'TRENDS NEUROSCIENCES')

# %%
df['clean_journal'].value_counts()
# Out:
# PLOS ONE                                            209
# JOURNAL BIOLOGICAL CHEMISTRY                         65
# NEUROIMAGE                                           31
# NUCLEIC ACIDS RESEARCH                               29
# PLOS GENETICS                                        24
# PLOS PATHOGENS                                       24
# PROCEEDINGS NATIONAL ACADEMY SCIENCES                22
# PLOS NEGLECTED TROPICAL DISEASES                     20
# HUMAN MOLECULAR GENETICS                             19
# NATURE COMMUNICATIONS                                19
# MOVEMENT DISORDERS                                   15
# BMC PUBLIC HEALTH                                    15
# BIOCHEMICAL JOURNAL                                  15
# JOURNAL NEUROSCIENCE                                 15
# BRAIN                                                14
# DEVELOPMENTAL CELL                                   12
# CURRENT BIOLOGY                                      12
# JOURNAL GENERAL VIROLOGY                             11
# FASEB JOURNAL                                        11
# BMJ                                                  10
# MALARIA JOURNAL                                      10
# PLOS COMPUTATIONAL BIOLOGY                           10
# AMERICAN JOURNAL HUMAN GENETICS                      10
# JOURNAL VIROLOGY                                      9
# NEURON                                                9
# EMBO JOURNAL                                          9
# BMJ OPEN                                              9
# HEPATOLOGY                                            9
# DEVELOPMENT                                           9
# JOURNAL PHYSIOLOGY                                    9
#                                                    ...
# JOURNAL ABNORMAL CHILD PSYCHOLOGY AND PSYCHIATRY      1
# AMERICAN CHEMICAL SOCIETY                             1
# MOLECULAR GENETICS AND METABOLISM                     1
# HEART                                                 1
# JOURNAL MECHANISMS AGEING AND DEVELOPMENT             1
# CENTAURUS                                             1
# EUROPEAN NEUROPSYCHOPHARMACOLOGY                      1
# INTERNATIONAL JOURNAL EPIDEMIOL                       1
# BMC RESEARCH NOTES                                    1
# CLINICAL RADIOLOGY                                    1
# CRIMINAL BEHAVIOR AND MENTAL HEALTH                   1
# EXPERT REVIEWS MOLECULAR MEDICINE                     1
# EVODEVO                                               1
# JOURNAL EXPERIMENTAL NANOSCIENCE                      1
# EUROPEAN JOURNAL PUBLIC HEALTH                        1
# FRONTIERS INVERTEBRATE PHYSIOLOGY                     1
# ANGEW CHEMS INTERNATIONAL ED                          1
# CIRCULATION RESEARCH                                  1
# PLOS MEDICINE JOURNAL                                 1
# METABOLOMICS                                          1
# BIOMED CENTRAL                                        1
# IMMUNOLOGY LETTERS                                    1
# OPHTHALMOLOGY                                         1
# OSTEOPOROSIS INTERNATIONALERNATIONAL                  1
# LIPIDS HEALTH AND DISEASE                             1
# ACTA F                                                1
# ACS CHEMICAL NEUROSCIENCE                             1
# JOURNAL ABNORMAL PSYCHOLOGY                           1
# NEURODEGENERATIVE DISEASES                            1
# BIOCHEM JOURNAL                                       1
# Name: clean_journal, Length: 812, dtype: int64

# %%
#ACTA journals from International Union of Crystallography 
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'ACTA D' if 'ACTA CRYSTALLOGRAPHICA SECTION D' in x else x)
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'ACTA D' if 'ACTA CRYSTALLOGRAPHY D' in x else x)
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'ACTA F' if 'ACTA CRYSTALLOGRAPHICA SECTION F STRUCTURAL BIOLOGY AND CRYSTALLIZATION COMMUNICATIONS' in x else x)
#ACTA Neurpatholica
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'ACTA NEUROPATHOLOGICA' if 'ACTA NEUROPATHOL' in x else x)
#BIOLOGY OPEN
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'BIOLOGY OPEN' if 'BIOL OPEN' in x else x)
#AIDS Journal by Wolters Kluwer
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'AIDS JOURNAL' if 'AIDS' == x else x)
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'AIDS JOURNAL' if 'AIDS UK' == x else x)
#CHILD CARE HEATH AND DEVELOPMENT
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'CHILD CARE HEATH AND DEVELOPMENT' \
                                                if 'CHILD CARE HEALTH DEVELOPMENT' in x else x)
#BIOCHIMICA ET BIOOHYSICA ACTA MOLECULAR BASIS DISEASE
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'BIOCHIMICA ET BIOPHYSICA ACTA MOLECULAR BASIS DISEASE' \
                                                if 'BBA ' in x else x)
#CLINICAL INFECTIOUS DISEASES
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'CLINICAL INFECTIOUS DISEASES' \
                                                if 'CLINICLA INFECTIOUS DISEASE' in x else x)
#JOURNAL INFECTIOUS DISEASES
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL INFECTIOUS DISEASES' \
                                                if 'J INFECT DIS' in x else x)
#EMBO JOURNAL
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'EMBO JOURNAL' if 'EMBO' == x else x)
#EUROPEAN JOURNAL IMMUNOLOGY
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'EUROPEAN JOURNAL IMMUNOLOGY' if 'EUR JOURNAL IMMUNOL' in x else x)
#FEBS JOURNAL
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'FEBS JOURNAL' if 'FEBS J' == x else x)
#JOURNAL CLINICAL VIROLOGY
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL CLINICAL VIROLOGY' if 'VIROLOGY' == x else x)
#HUMAN MUTATION
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'HUMAN MUTATION' if 'HUMAN MUTATION' in x else x)
#JOURNAL ACQUIRED IMMUNE DEFICIENCY SYNDROMES
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL ACQUIRED IMMUNE DEFICIENCY SYNDROMES'\
                                                if 'ACQUIRED IMMUNE DEFICIENCY' in x else x)
#JOURNAL IMMUNOLOGY
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL IMMUNOLOGY' if 'J IMMUNOL' in x else x)
#JOURNAL CELL SCIENCE
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL CELL SCIENCE' if 'J CELL SCI' in x else x)
#JOURNAL CLINICAL MICROBIOLOGY
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL CLINICAL MICROBIOLOGY' if 'J CLIN MICROBIOL' in x else x)
#JOURNAL MEDICINAL CHEMISTRY
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL MEDICINAL CHEMISTRY' if 'J MED CHEM' == x else x)
#JOURNAL MECHANISMS AGEING AND DEVELOPMENT
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL MECHANISMS AGEING AND DEVELOPMENT' \
                                                if 'MECHANISMS AGEING AND DEVELOPMENT' in x else x)
#JOURNAL MICROBIOLOGY
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'JOURNAL MICROBIOLOGY' if 'MICROBIOLOGY' == x else x)
#PARASITES AND VECTORS
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'PARASITES AND VECTORS' if 'PARASIT VECTORS' == x else x)
#PROCEEDINGS NATIONAL ACADEMY SCIENCES
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'PROCEEDINGS NATIONAL ACADEMY SCIENCES' if 'PNAS' in x else x)
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'PROCEEDINGS NATIONAL ACADEMY SCIENCES' if 'PROCEDDINGS' in x else x)
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'PROCEEDINGS NATIONAL ACADEMY SCIENCES' \
                                                if 'PROC NATL ACAD SCI U S A' in x else x)
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'PROCEEDINGS NATIONAL ACADEMY SCIENCES' \
                                                if 'PROCEEDINGS NATIONAL ACADEMY SCIENCES UNITED STATES AMERICA' in x else x)
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'PROCEEDINGS NATIONAL ACADEMY SCIENCES' \
                                                if 'PROCEEDINGS NATIONAL ACADEMY SCIENCES USA' in x else x)
#Public Library of Science
df['clean_journal'] = df['clean_journal'].apply(lambda x: 'PLOS ONE' if 'PLOS' == x else x)

# %%
df['clean_journal'] = df['clean_journal'].str.strip()
df['clean_journal'].value_counts()
# Out:
# PLOS ONE                                                                        213
# JOURNAL BIOLOGICAL CHEMISTRY                                                     65
# PROCEEDINGS NATIONAL ACADEMY SCIENCES                                            37
# NEUROIMAGE                                                                       31
# NUCLEIC ACIDS RESEARCH                                                           29
# PLOS GENETICS                                                                    24
# PLOS PATHOGENS                                                                   24
# PLOS NEGLECTED TROPICAL DISEASES                                                 20
# HUMAN MOLECULAR GENETICS                                                         19
# NATURE COMMUNICATIONS                                                            19
# BMC PUBLIC HEALTH                                                                15
# JOURNAL NEUROSCIENCE                                                             15
# BIOCHEMICAL JOURNAL                                                              15
# MOVEMENT DISORDERS                                                               15
# BRAIN                                                                            14
# JOURNAL MEDICINAL CHEMISTRY                                                      13
# DEVELOPMENTAL CELL                                                               12
# CURRENT BIOLOGY                                                                  12
# JOURNAL GENERAL VIROLOGY                                                         11
# FASEB JOURNAL                                                                    11
# EMBO JOURNAL                                                                     10
# AMERICAN JOURNAL HUMAN GENETICS                                                  10
# PLOS COMPUTATIONAL BIOLOGY                                                       10
# MALARIA JOURNAL                                                                  10
# BMJ                                                                              10
# CELL REPORTS                                                                      9
# JOURNAL PHYSIOLOGY                                                                9
# DEVELOPMENT                                                                       9
# NEURON                                                                            9
# JOURNAL INFECTIOUS DISEASES                                                       9
#                                                                                ...
# AMERICAN JOURNAL MEDICAL GENETICS                                                 1
# REPRODUCTIVE SCIENCES                                                             1
# INTERNATIONALERNATIONAL JOURNAL APPLIED EARTH OBSERVATION AND GEOINFORMATION      1
# INTERNATIONALERNATIONAL JOURNAL TUBERCULOSIS AND LUNG DISEASE                     1
# ACTA PHYSIOL                                                                      1
# CHEST                                                                             1
# SOCIAL STUDIES SCIENCE                                                            1
# ZOONOSES AND PUBLIC HEALTH                                                        1
# THORAX AN INTERNATIONALERNATIONAL JOURNAL RESPIRATORY MEDICINE                    1
# ASN NEURO                                                                         1
# PSYCHOLOGICAL TRAUMA THEORY RESEARCH PRACTICE AND POLICY                          1
# VETERINARY RECORD                                                                 1
# NATURE SCIENTIFIC REPORTS                                                         1
# PHILOSOPHICAL TRANSACTIONS ROYAL SOCIETY LONDON SERIES B BIOLOGICAL SCIENCES      1
# BMJ QUALITY AND SAFETY                                                            1
# JOURNAL APPLIED PHYSIOLOGY                                                        1
# MOLECLUAR AND CELLULAR ENDOCRINOLOGY                                              1
# JOURNAL PUBLIC HEALTH                                                             1
# ORGANIC AND BIOMOLECULAR CHEMISTRY                                                1
# J MOLECULAR BIOLOGYL                                                              1
# JOURNAL EVOLUTIONARY BIOLOGY                                                      1
# JOURNAL FAMILY PSYCHOLOGY                                                         1
# MOLECULAR AND CELLULAR BIOLOGY                                                    1
# STUDIES HISTORY AND PHILOSOPHY SCIENCE PART C                                     1
# NEPHRON PHYSIOLOGY                                                                1
# VET JOURNAL                                                                       1
# ANNALS SCIENCE                                                                    1
# FRONTIERS COGNITIVE SCIENCE                                                       1
# BMC MEDICAL IMAGING                                                               1
# HBM JOURNAL HUMAN BRAIN MAPPING                                                   1
# Name: clean_journal, Length: 779, dtype: int64

# %%
df.groupby('clean_journal').count()
# Out:
#                                                     ID  Publisher  Journal  \
# clean_journal
# ACADEMY NUTRITION AND DIETETICS                      1          1        1
# ACS CHEMICAL BIOLOGY                                 4          5        5
# ACS CHEMICAL NEUROSCIENCE                            1          1        1
# ACS NANO                                             2          2        2
# ACTA D                                               5          5        5
# ACTA DERMATO VENEREOLOGICA                           1          1        1
# ACTA DIABETOLOGICA                                   1          1        1
# ACTA F                                               3          3        3
# ACTA NEUROPATHOLOGICA                                3          4        4
# ACTA OPTHALMOLOGICA                                  1          1        1
# ACTA PHYSIOL                                         1          1        1
# ADDICTION                                            2          2        2
# ADVANCES EXPERIMENTAL MEDICINE AND BIOLOGY           0          4        4
# AGE                                                  2          2        2
# AGE AND AGEING                                       1          1        1
# AGEING AND SOCIETY                                   0          1        1
# AGING CELL                                           1          1        1
# AIDS BEHAV                                           1          1        1
# AIDS CARE                                            4          4        4
# AIDS JOURNAL                                         6          6        6
# AIDS RESEARCH AND THERAPY                            1          1        1
# ALCOHOL AND ALCOHOLISM                               1          1        1
# ALIMENTRARY PHARMACOLOGY AND THERAPEUTICS            2          2        2
# AM JOURNAL BIOETH                                    1          1        1
# AM JOURNAL TROP MED HYG                              1          1        1
# AMERICAN CHEMICAL SOCIETY                            1          1        1
# AMERICAN ETHNOLOGIST                                 0          2        2
# AMERICAN JOURNAL BIOETHICS--NEUROSCIENCE             1          1        1
# AMERICAN JOURNAL CLINICAL NUTRITION                  2          2        2
# AMERICAN JOURNAL EPIDEMIOLOGY                        4          4        4
# ...                                                 ..        ...      ...
# TISSUE ENGINEERING PART A                            1          1        1
# TRAFFIC                                              5          6        6
# TRANSACTIONS ROYAL SOCIETY TROPICAL MEDICINE AN...   1          1        1
# TRANSLATIONAL PSYCHIATRY                             2          2        2
# TRENDS COGNITIVE SCIENCE                             1          1        1
# TRENDS GENETICS                                      2          2        2
# TRENDS MICROBIOLOGY                                  1          1        1
# TRENDS MOLECULAR MEDICINE                            1          1        1
# TRENDS NEUROSCIENCES                                 1          1        1
# TRENDS NEUROSCIENCESS                                1          2        2
# TRENDS PARASITOLOGY                                  0          4        4
# TRIALS                                               5          5        5
# TROP MED INTERNATIONAL HEALTH                        1          1        1
# TROPICAL ANIMAL HEALTH AND PRODUCTION                1          1        1
# TROPICAL MEDICINE AND INTERNATIONALERNATIONAL H...   5          6        6
# TUBERCULOSIS                                         2          2        2
# URBAN HISTORY                                        0          1        1
# UROLITHIASIS                                         1          1        1
# VACCINE                                              5          5        5
# VASCULAR PHARMACOLOGY                                1          1        1
# VET JOURNAL                                          1          1        1
# VETERINARY MICROBIOLOGY                              1          1        1
# VETERINARY PARASITOLOGY                              1          2        2
# VETERINARY RECORD                                    1          1        1
# VETERINARY RESEARCH                                  1          1        1
# VIROLOGY JOURNAL                                     1          1        1
# VIRUS RESEARCH                                       1          1        1
# VISION RESEARCH                                      2          2        2
# VISUAL NEUROSCIENCE                                  1          1        1
# ZOONOSES AND PUBLIC HEALTH                           1          1        1
#
#                                                     Article  Cost
# clean_journal
# ACADEMY NUTRITION AND DIETETICS                           1     1
# ACS CHEMICAL BIOLOGY                                      5     5
# ACS CHEMICAL NEUROSCIENCE                                 1     1
# ACS NANO                                                  2     2
# ACTA D                                                    5     5
# ACTA DERMATO VENEREOLOGICA                                1     1
# ACTA DIABETOLOGICA                                        1     1
# ACTA F                                                    3     3
# ACTA NEUROPATHOLOGICA                                     4     4
# ACTA OPTHALMOLOGICA                                       1     1
# ACTA PHYSIOL                                              1     1
# ADDICTION                                                 2     2
# ADVANCES EXPERIMENTAL MEDICINE AND BIOLOGY                4     4
# AGE                                                       2     2
# AGE AND AGEING                                            1     1
# AGEING AND SOCIETY                                        1     1
# AGING CELL                                                1     1
# AIDS BEHAV                                                1     1
# AIDS CARE                                                 4     4
# AIDS JOURNAL                                              6     6
# AIDS RESEARCH AND THERAPY                                 1     1
# ALCOHOL AND ALCOHOLISM                                    1     1
# ALIMENTRARY PHARMACOLOGY AND THERAPEUTICS                 2     2
# AM JOURNAL BIOETH                                         1     1
# AM JOURNAL TROP MED HYG                                   1     1
# AMERICAN CHEMICAL SOCIETY                                 1     1
# AMERICAN ETHNOLOGIST                                      2     2
# AMERICAN JOURNAL BIOETHICS--NEUROSCIENCE                  1     1
# AMERICAN JOURNAL CLINICAL NUTRITION                       2     2
# AMERICAN JOURNAL EPIDEMIOLOGY                             4     4
# ...                                                     ...   ...
# TISSUE ENGINEERING PART A                                 1     1
# TRAFFIC                                                   6     6
# TRANSACTIONS ROYAL SOCIETY TROPICAL MEDICINE AN...        1     1
# TRANSLATIONAL PSYCHIATRY                                  2     2
# TRENDS COGNITIVE SCIENCE                                  1     1
# TRENDS GENETICS                                           2     2
# TRENDS MICROBIOLOGY                                       1     1
# TRENDS MOLECULAR MEDICINE                                 1     1
# TRENDS NEUROSCIENCES                                      1     1
# TRENDS NEUROSCIENCESS                                     2     2
# TRENDS PARASITOLOGY                                       4     4
# TRIALS                                                    5     5
# TROP MED INTERNATIONAL HEALTH                             1     1
# TROPICAL ANIMAL HEALTH AND PRODUCTION                     1     1
# TROPICAL MEDICINE AND INTERNATIONALERNATIONAL H...        6     6
# TUBERCULOSIS                                              2     2
# URBAN HISTORY                                             1     1
# UROLITHIASIS                                              1     1
# VACCINE                                                   5     5
# VASCULAR PHARMACOLOGY                                     1     1
# VET JOURNAL                                               1     1
# VETERINARY MICROBIOLOGY                                   1     1
# VETERINARY PARASITOLOGY                                   2     2
# VETERINARY RECORD                                         1     1
# VETERINARY RESEARCH                                       1     1
# VIROLOGY JOURNAL                                          1     1
# VIRUS RESEARCH                                            1     1
# VISION RESEARCH                                           2     2
# VISUAL NEUROSCIENCE                                       1     1
# ZOONOSES AND PUBLIC HEALTH                                1     1
#
# [779 rows x 5 columns]

# %%
df1 = df['clean_journal'].value_counts()

# %%
df.clean_journal.unique()
# Out:
# array(['PSYCHOLOGICAL MEDICINE', 'BIOMACROMOLECULES',
#        'JOURNAL MEDICINAL CHEMISTRY', 'J ORG CHEM',
#        'JOURNAL PROTEOME RESEARCH', 'MOL PHARM', 'ACS CHEMICAL BIOLOGY',
#        'JOURNAL CHEMICAL INFORMATION AND MODELING', 'BIOCHEMISTRY',
#        'GASTROENTEROLOGY', 'JOURNAL BIOLOGICAL CHEMISTRY',
#        'JOURNAL IMMUNOLOGY', 'ACS CHEMICAL NEUROSCIENCE', 'ACS NANO',
#        'AMERICAN CHEMICAL SOCIETY', 'ANALYTICAL CHEMISTRY',
#        'BIOCONJUGATE CHEMISTRY', 'JOURNAL AMERICAN CHEMICAL SOCIETY',
#        'CHEST', 'JOURNAL NEUROPHYSIOLOGY', 'JOURNAL PHYSIOLOGY',
#        'AMERICAN JOURNAL PSYCHIATRY', 'BEHAVIORAL NEUROSCIENCE', 'EMOTION',
#        'HEALTH PSYCHOLOGY', 'JOURNAL ABNORMAL PSYCHOLOGY',
#        'JOURNAL CONSULTING AND CLINICAL PSYCHOLOGY',
#        'JOURNAL EXPERIMENTAL PSYCHOLOGY ANIMAL BEHAVIOR PROCESS',
#        'JOURNAL EXPERIMENTAL PSYCHOLOGY HUMAN PERCEPTION AND PERFORMANCE',
#        'JOURNAL FAMILY PSYCHOLOGY', 'PSYCHOLOGICAL ASSESSMENT',
#        'PSYCHOLOGICAL REVIEW',
#        'PSYCHOLOGICAL TRAUMA THEORY RESEARCH PRACTICE AND POLICY',
#        'AMERICAN JOURNAL PUBLIC HEALTH', 'J BIOLOGICAL CHEMISTRY',
#        'AMERICAN JOURNAL PATHOLOGY',
#        'ANTIMICROBIAL AGENTS AND CHEMOTHERAPY',
#        'CLINICAL AND VACCINE IMMUNOLOGY', 'EUKARYOTIC CELL',
#        'INFECTION AND IMMUNITY', 'JOURNAL BACTERIOLOGY',
#        'JOURNAL VIROLOGY', 'MBIO', 'MOLECULAR AND CELLULAR BIOLOGY',
#        'JOURNAL CLINICAL MICROBIOLOGY', 'AMERICAN SOCIETY NUTRITION',
#        'BLOOD', 'BLOOD JOURNAL 2012', 'AMERICAN JOURNAL HUMAN GENETICS',
#        'JOUNRAL CLINICAL MICROBIOLOGY',
#        'SPEECH LANGUAGE AND HEARING RESEARCH', 'BIOLOGICAL CHEMISTRY',
#        'J BIOLOGICAL CHEMISTRYISTRY',
#        'MCP (MOLECULAR AND CELLULAR PROTEOMICS)',
#        'MOLECULAR AND CELLULAR PROTEOMICS', 'JOURNAL VISION',
#        'CURRENT TOPICS MEDICINAL CHEMISTRY',
#        'CURRENT ANALYTICAL CHEMISTRY',
#        'EVIDENCE ETHOS AND EXPERIMENT ANTHROPOLOGY AND HISTORY MEDICAL RESEARCH AFRICA',
#        'BIOCHEM JOURNAL', 'MOLECULAR CELL',
#        'ARTHRITIS RESEARCH AND THERAPY', 'BIOMED CENTRAL',
#        'BMC PUBLIC HEALTH', 'BMC BIOLOGY', 'BMC GENETICS',
#        'BMC GENOME BIOLOGY', 'BMC GENOMICS',
#        'BMC HEALTH SERVICES RESEARCH', 'BMC MEDICAL GENETICS',
#        'BMC MEDICINE', 'BMC MICROBIOLOGY', 'BMC MOLECULAR BIOLOGY',
#        'BMC NEUROLOGY', 'BMC NEUROSCIENCE', 'BMC PSYCHIATRY',
#        'BMC RESEARCH NOTES', 'BMC VETERINARY RESEARCH',
#        'CLINICAL PROTEOMICS', 'EVODEVO', 'GENOME BIOLOGY',
#        'GENOME MEDICINE', 'INTERNATIONALERNATIONAL JOURNAL EQUITY HEALTH',
#        'INTERNATIONALERNATIONAL JOURNAL BEHAVIORAL NUTRITION AND PHYSICAL ACTIVITY',
#        'INTERNATIONALERNATIONAL JOURNAL HEALTH GEOGRAPHICS',
#        'JOURNAL CHEMINFORMATICS', 'JOURNAL NEUROINFLAMMATION',
#        'LIPIDS HEALTH AND DISEASE', 'MALARIA JOURNAL', 'MOLECULAR BRAIN',
#        'MOLECULAR PAIN', 'NUTRITION JOURNAL',
#        'ORPHANET JOURNAL RARE DISEASES', 'PARASITES AND VECTORS',
#        'PUBLIC HEALTH', 'RESPIRATORY RESEARCH', 'VIROLOGY JOURNAL',
#        'BMC INFECTIOUS DISEASES', 'HUMAN RESOURCES HEALTH',
#        'IMPLEMENT SCI', 'AIDS RESEARCH AND THERAPY', 'BMC PEDIATRICICS',
#        'TRIALS', 'VETERINARY RESEARCH', 'BIOPHYSICAL JOURNAL',
#        'EUROPEAN JOURNAL ENDOCRINOLOGY', 'JOURNAL ENDOCRINOLOGY',
#        'JOURNAL MOLECULAR ENDOCRINOLOGY',
#        'REPRODUCTION(CAMBRIDGE ENGLAND)', 'CELLULAR MICROBIOLOGY',
#        'BMC MEDICAL ETHICS', 'BMC MEDICAL IMAGING',
#        'COST EFFECTIVENESS AND RESOURCE ALLOCATION', 'BJOPHTHALMOL', 'BMJ',
#        'BMJ OPEN', 'BRITISH JOURNAL OPHTHALMOLOGY',
#        'BRITISH JOURNAL OPTHALMOLOGY', 'BRITISH MEDICAL JOURNAL',
#        'FRONTLINE GASTROENTEROLOGY', 'JOURNAL CLINICAL PATHOLOGY',
#        'JOURNAL EPIDEMIOLOGY AND COMMUNITY HEALTH',
#        'JOURNAL MEDICAL ETHICS', 'JOURNAL MEDICAL GENETICS',
#        'JOURNAL NEUROLOGY NEUROSURGERY AND PSYCHIATRY',
#        'SEXUALLY TRANSMITTED INFECTIONS', 'GUT',
#        'ARCHIVES DISEASE CHILDHOOD', 'BMJ QUALITY AND SAFETY', 'HEART',
#        'MEDICAL HUMANITIES', 'THORAX', 'POSTGRADUATE MEDICAL JOURNAL',
#        'VETERINARY RECORD',
#        'THORAX AN INTERNATIONALERNATIONAL JOURNAL RESPIRATORY MEDICINE',
#        'EUROPEAN JOURNAL HEALTH LAW', 'JOURNAL NEUROSCIENCE',
#        'HEART AND CIRCULATORY PHYSIOLOGY',
#        'INTERNATIONALERNATIONAL PSYCHOGERIATRICS', 'PARASITOLOGY',
#        'MEDICAL HISTORY', 'AGEING AND SOCIETY',
#        'BRITISH JOURNAL HISTORY SCIENCE', 'EPIDEMIOLOGY AND INFECTION',
#        'EXPERT REVIEWS MOLECULAR MEDICINE',
#        'INTERNATIONALERNATIONAL JOURNAL LAW CONTEXT',
#        'JOURNAL INTERNATIONALERNATIONAL NEUROPSYCHOLOGICAL SOCIETY',
#        'PUBLIC HEALTH NUTRITION', 'PYSCHOLOGICAL MEDICINE',
#        'URBAN HISTORY', 'VISUAL NEUROSCIENCE', 'STEM CELL REPORTS',
#        'JOURNAL CLINICAL ENDOCRINOLOGY AND METABOLISM', 'JOURNAL VIROL',
#        'JOURNAL INTERNATIONALERNATIONAL AIDS SOCIETY',
#        'GENES AND DEVELOPMENT', 'LEARNING AND MEMORY', 'GENOME RESEARCH',
#        'RNA', 'JOURNAL CELL SCIENCE', 'BIOLOGY OPEN', 'DEVELOPMENT',
#        'DEVELOPMENTAL CELL', 'DISEASE MODELS AND MECHANISMS',
#        'INTERNATIONALERNATIONAL REVIEWS IMMUNOLOGY',
#        'JOURNAL INTERNATIONALERNATIONAL AFRICAN INSTITUTE', 'CELL REPORTS',
#        'AMERICAN JOURNAL CLINICAL NUTRITION', 'CELL PRESS CELL REPORTS',
#        'G3 GENES GENOMES GENETICS', 'GENETICS',
#        'PROCEEDINGS NATIONAL ACADEMY SCIENCES', 'JOURNAL NUTRITION',
#        'NEUROIMAGE', 'ACADEMY NUTRITION AND DIETETICS',
#        'AMERICAN JOURNAL GERIATRIC PSYCHIATRY',
#        'AMERICAN JOURNAL PREVENTIVE MEDICINE', 'ANALYTICAL BIOCHEMISTRY',
#        'ANIMAL BEHAVIOR', 'APPLIED ENERGY', 'ASIAN JOURNAL PSYCHIATRY',
#        'ATHEROSCLEROSIS',
#        'BIOCHIMICA ET BIOPHYSICA ACTA MOLECULAR BASIS DISEASE',
#        'BEHAVIOR RESEARCH AND THERAPY', 'BEHAVIORAL BRAIN RESEARCH',
#        'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS',
#        'BIOCHEMICAL PHARMACOLOGY',
#        'BIOCHIMICA ET BIOPHYSICA ACTA GENE REGULATORY MECHANISMS',
#        'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) MOLECULAR CELL RESEARCH',
#        'BIOCHIMIE', 'BIOLOGICAL PSYCHIATRY', 'BIOLOGICAL PSYCHOLOGY',
#        'BIOMATERIALS', 'BIOSYSTEMS', 'BONE', 'BRAIN AND COGNITION',
#        'BRAIN AND LANGUAGE', 'BRAIN RESEARCH', 'CANCER LETTERS', 'CELL',
#        'CELL CALCIUM', 'CELL HOST AND MICROBE', 'CELL JOURNAL',
#        'CELL METABOLISM', 'CELL STEM CELL', 'CELLULAR SIGNALLING',
#        'CHEMSITRY AND BIOLOGY', 'CLINICAL NEUROLOGY AND NEUROSURGERY',
#        'CLINICAL RADIOLOGY', 'COGNITION', 'COGNITIVE DEVELOPMENT',
#        'CONSCIOUSNESS AND COGNITION', 'CORTEX', 'CURRENT BIOLOGY',
#        'CURRENT OPINION NEUROBIOLOGY', 'CURRENT OPINION MICROBIOLOGY',
#        'CURRENT OPINIONS NEUROBIOLOGY', 'DEVELOPMENT CELL',
#        'DEVELOPMENTAL BIOLOGY', 'DEVELOPMENTAL COGNITIVE NEUROSCIENCE',
#        'DIAGNOSTIC MICROBIOLOGY AND INFECTIOUS DISEASE', 'ELSEVIER',
#        'ENDEAVOUR', 'EPILEPSY RESEARCH', 'EUROPEAN JOURNAL CELL BIOLOGY',
#        'EUROPEAN JOURNAL MEDICAL GENETICS',
#        'EUROPEAN NEUROPSYCHOPHARMACOLOGY', 'EXPERIMENTAL CELL RESEARCH',
#        'EXPERIMENTAL EYE RESEARCH', 'EXPERIMENTAL HEMATOLOGY',
#        'EXPERIMENTAL NEUROLOGY', 'EXPERIMENTAL PARASITOLOGY',
#        'FEBS LETTERS', 'FEBS OPEN BIO', 'FERTILITY AND STERILITY',
#        'FREE RADICAL AND BIOLOGY MEDICINE', 'FUNGAL BIOLOGY',
#        'FUNGAL ECOLOGY', 'GENE', 'GENE THERAPY', 'HEALTH AND PLACE',
#        'IMMUNOBIOLOGY', 'IMMUNITY', 'IMMUNOLOGY LETTERS',
#        'INFECTION GENETICS AND EVOLUTION',
#        'INTERNATIONAL JOURNAL PARASITOLOGY',
#        'INTERNATIONALERNATIONAL HEALTH',
#        'INTERNATIONALERNATIONAL JOURNAL PARASITOLOGY',
#        'INTERNATIONALERNATIONAL JOURNAL APPLIED EARTH OBSERVATION AND GEOINFORMATION',
#        'INTERNATIONALERNATIONAL JOURNAL BIOCHEMISTRY AND CELL BIOLOGY',
#        'INTERNATIONALERNATIONAL JOURNAL CARDIOLOGY',
#        'J MOLECULAR BIOLOGYL', 'J STEROID BIOCHEM MOLECULAR BIOLOGYL',
#        'JOURNAL AFFECTIVE DISORDERS',
#        'JOURNAL ALLERGY AND CLINICAL IMMUNOLOGY',
#        'JOURNAL ANTHROPOLOGICAL ARCHAEOLOGY',
#        'JOURNAL ARCHAEOLOGICAL SCIENCE',
#        'JOURNAL BEHAVIOR THERAPY AND EXPERIMENTAL PSYCHIATRY',
#        'JOURNAL CLINICAL EPIDEMIOLOGY', 'JOURNAL CLINICAL VIROLOGY',
#        'JOURNAL CYCSTIC FIBROSIS', 'JOURNAL HEPATOLOGY',
#        'JOURNAL HISTORICAL GEOGRAPHY', 'JOURNAL HOSPITAL INFECTIONS',
#        'JOURNAL INFECTION', 'JOURNAL MECHANISMS AGEING AND DEVELOPMENT',
#        'JOURNAL MOLECULAR BIOLOGY', 'JOURNAL NEUROSCIENCE METHODS',
#        'JOURNAL NUTRITION EDUCATION AND BEHAVIOR',
#        'JOURNAL PAEDIATRIC UROLOGY', 'JOURNAL PROTEOMICS',
#        'JOURNAL STRUCTURAL BIOLOGY',
#        'JOURNAL AMERICAN ACADEMY CHILD AND ADOLESCENT PSYCHIATRY',
#        'JOURNAL AMERICAN COLLEGE CARDIOLOGY',
#        'JOURNAL NEUROLOGICAL SCIENCES', 'JOURNAL TRANSPORT GEOGRAPHY',
#        'JOURNAL VIROLOGICAL METHODS', 'LANCET', 'LANCET GLOBAL HEALTH',
#        'LEARNING AND INDIVIDUAL DIFFERENCES', 'MATRIX BIOLOGY',
#        'MATURITAS', 'MICROBES AND INFECTION', 'MOLECULAR BIOLOGY',
#        'MOLECLUAR AND CELLULAR ENDOCRINOLOGY',
#        'MOLECULAR AND BIOCHEMICAL PARASITOLOGY',
#        'MOLECULAR AND CELLULAR ENDOCRINOLOGY',
#        'MOLECULAR GENETICS AND METABOLISM', 'MOLECULAR IMMUNOLOGY',
#        'MOLECULAR PHYLOGENETICS AND EVOLUTION', 'N BIOTECHNOL',
#        'NEUROBIOLOGY AGING', 'NEUROBIOLOGY DISEASE',
#        'NEUROBIOLOGY LEARNING AND MEMORY',
#        'NEUROCHEMISTRY INTERNATIONALERNATIONAL', 'NEUROIMAGE CLINICAL',
#        'NEUROMUSCULAR DISORDERS', 'NEURON', 'NEUROPHARMACOLOGY',
#        'NEUROPHYSIOLOGIA', 'NEUROPSYCHOLOGIA', 'NEUROSCIENCE',
#        'NEUROSCIENCE AND BEHAVIORAL REVIEWS', 'NEUROSCIENCE LETTERS',
#        'NITRIC OXIDE', 'OPHTHALMOLOGY', 'OSTEOARTHRITIS AND CARTILAGE',
#        'PAIN', 'PARKINSONISM AND RELATED DISORDERS', 'PARSITOLOGY',
#        'PERSONALITY AND INDIVIDUAL DIFFERENCES', 'PREVENTIVE MEDICINE',
#        'PROTEIN EXPR PURIF', 'PROTIST',
#        'PULMONARY PHARMACOLOGY AND THERAPEUTICS',
#        'RESEARCH VETERINARY SCIENCE', 'SCHIZOPHRENIA RESEARCH', 'SEIZURE',
#        'SEMINARS ONCOLOGY', 'SOCIAL SCIENCE AND MEDICINE',
#        'STEM CELL RESEARCH', 'STRUCTURE',
#        'STUDIES HISTORY AND PHILOSOPHY SCIENCE PART C',
#        'STUDIES HISTORY AND PHILOSOPHY SCIENCE PART C STUDIES HISTORY AND PHILOSOPHY BIOLOGICAL AND BIOMEDICAL SCIENCES',
#        'TETRAHEDRON LETTERS',
#        'JOURNAL STEROID BIOCHEMISTRY AND MOLECULAR BIOLOGY',
#        'LANCET NEUROLOGY', 'VET JOURNAL', 'TICKS AND TICK-BORNE DISEASES',
#        'TRANSACTIONS ROYAL SOCIETY TROPICAL MEDICINE AND HYGIENE',
#        'TRENDS COGNITIVE SCIENCE', 'TRENDS GENETICS',
#        'TRENDS MICROBIOLOGY', 'TRENDS MOLECULAR MEDICINE',
#        'TRENDS NEUROSCIENCES', 'TRENDS NEUROSCIENCESS',
#        'TRENDS PARASITOLOGY', 'TUBERCULOSIS', 'VACCINE',
#        'VASCULAR PHARMACOLOGY', 'VETERINARY MICROBIOLOGY',
#        'VETERINARY PARASITOLOGY', 'VIRUS RESEARCH', 'VISION RESEARCH',
#        'LANCET INFECT DIS', 'MATH BIOSCI', 'ENDOCRINOLOGY',
#        'MOLECULAR ENDOCRINOLOGY', 'EUROPEAN RESPIRATORY JOURNAL',
#        'FASEB JOURNAL', 'JOURNAL LEUKOCYTE BIOLOGY', 'HAEMATOLOGICA',
#        'HAEMATOLOGICA/HAEMATOLOGY JOURNAL',
#        'FRONTIERS AUDITORY COGNITIVE NEUROSCIENCE',
#        'FRONTIERS BEHAVIORAL NEUROSCIENCE',
#        'FRONTIERS BRAIN IMAGING METHODS',
#        'FRONTIERS CELLULAR NEUROSCIENCE', 'FRONTIERS COGNITION',
#        'FRONTIERS COGNITIVE SCIENCE', 'FRONTIERS DECISION NEUROSCIENCE',
#        'FRONTIERS DEVELOPMENTAL PSYCHOLOGY', 'FRONTIERS ELECTROPHYSIOLOGY',
#        'FRONTIERS ENDOCRINOLOGY', 'FRONTIERS GENETICS',
#        'FRONTIERS HUMAN NEUROSCIENCE', 'FRONTIERS IMMUNOLOGICAL MEMORY',
#        'FRONTIERS INFLAMMATION', 'FRONTIERS INVERTEBRATE PHYSIOLOGY',
#        'FRONTIERS MOLECULAR NEUROSCIENCE', 'FRONTIERS SCHIZOPHRENIA',
#        'FRONTIERS SYSTEMS NEUROSCIENCE',
#        'FRONTIERS INTERNATIONALEGRATIVE NEUROSCIENCE',
#        'FRONTIERS PERCEPTION SCIENCE', 'FRONTIERS CONSCIOUSNESS RESEARCH',
#        'FRONTIERS IMMUNOLOGY', 'FRONTIERS NEURAL CIRCUITS',
#        'FRONTIERS NEUROROBOTICS', 'FRONTIERS T CELL BIOLOGY',
#        'FUTURE NEUROLOGY', 'FUTURE VIROLOGY', 'FUTURE MICROBIOLOGY',
#        'FUTURE MEDICINAL CHEMISTRY',
#        'INTERNATIONALERNATIONAL JOURNAL RHEUMATOLOGY', 'JOURNAL ALLERGY',
#        'JOURNAL PARASITOLOGY RESEARCH',
#        'OXIDATIVE MEDICINE AND CELLULAR LONGEVITY',
#        'METHODS MOLECULAR BIOLOGY', 'ONCOTARGET',
#        'MOLECULAR MEMBRANE BIOLOGY',
#        'EXPERT REVIEWS ANTI-INFECTIVE CHEMOTHERAPY', 'NANOTECHNOLOGY',
#        'IJTLD',
#        'INTERNATIONALERNATIONAL JOURNAL TUBERCULOSIS AND LUNG DISEASE',
#        'ACTA D', 'ACTA F', 'J SYNCHROTRON RADIAT',
#        'JOURNAL APPLIED CRYSTALLOGRAPHY', 'PHYSICS BIOLOGY AND MEDICINE',
#        'JOURNAL ALZHEIMER DISEASE', 'THERANOSTICS',
#        'J MED INTERNATIONALERNET RESEARCH',
#        'AMERICAN JOURNAL MEDICAL GENETICS', 'GENETIC EPIDEMIOLOGY',
#        'JOURNAL PATHOLOGY', 'EUROPEAN JOURNAL IMMUNOLOGY',
#        'JOURNAL DEPRESSION AND ANXIETY',
#        'CLINICAL AND EXPERIMENTAL ALLERGY', 'EMBO MOLECULAR MEDICINE',
#        'BIOPOLYMERS', 'DEVELOPMENT SCIENCE', 'JOURNAL MEDICAL VIROLOGY',
#        'MOLECULAR MICROBIOLOGY', 'POPULATION SPACE AND PLACE', 'TRAFFIC',
#        'TROPICAL MEDICINE AND INTERNATIONALERNATIONAL HEALTH',
#        'HEPATOLOGY', 'BULLETIN HISTORY MEDICINE',
#        'NATIONAL ACADEMY SCIENCES', 'JOURNAL VISUALIZED EXPERIMENTS',
#        'JOURNAL NEUROLOGY AND TRANSLATIONAL NEUROSCIENCE',
#        'NEPHRON PHYSIOLOGY', 'NEURODEGENERATIVE DISEASES',
#        'NEUROEPIDEMIOLOGY', 'NEUROPSYCHOBIOLOGY', 'RESPIRATION',
#        'AUTOPHAGY', 'CELL ADHESION AND MIGRATION', 'CELL CYCLE',
#        'CHANNELS', 'EPIGENETICS', 'RNA BIOLOGY', 'NEUROLOGY',
#        'ANTIOXIDANTS AND REDOX SIGNALING', 'TISSUE ENGINEERING PART A',
#        'STEM CELLS AND DEVELOPMENT',
#        'INTERNATIONALERNATIONAL JOURNAL MOLECULAR SCIENCES', 'JERPH',
#        'SENSORS', 'JOURNAL COGNITIVE NEUROSCIENCE', 'BIOSOCIETIES',
#        'BRITISH JOURNAL CANCER', 'CELL DEATH AND DISEASE',
#        'CELL DEATH AND DIFFERENTIATION', 'FRONTIERS', 'GENETICS MEDICINE',
#        'JOURNAL CEREBRAL BLOOD FLOW AND METABOLISM',
#        'JOURNAL INVESTIGATIVE DERMATOLOGY', 'MUCOSAL IMMUNOLOGY',
#        'NATURE COMMUNICATIONS', 'SCIENTIFIC REPORTS', 'EMBO REPORTS',
#        'EUROPEAN JOURNAL HUMAN GENETICS', 'LEUKEMIA',
#        'NATURE NEUROSCIENCE', 'CELL DEATH DIFFERENTIATION', 'EMBO JOURNAL',
#        'INTERNATIONALERNATIONAL JOURNAL OBESITY',
#        'KIDNEY INTERNATIONALERNATIONAL', 'NATURE SCIENTIFIC REPORTS',
#        'NEUROPSYCHOPHARMACOLOGY', 'ONCOGENE', 'SCI REP',
#        'SCIENTIFIC REPORTS-11-00861B', 'TRANSLATIONAL PSYCHIATRY',
#        'OPTICS EXPRESS', 'ALCOHOL AND ALCOHOLISM',
#        'AMERICAN JOURNAL EPIDEMIOLOGY', 'BRAIN',
#        'BRIEFINGS BIOINFORMATICS', 'BRITISH MEDICAL BULLETIN',
#        'CEREBRAL CORTEX', 'CLINICAL INFECTIOUS DISEASES',
#        'CLINICAL INFECTIOUS DISEASES ONLINE',
#        'EUROPEAN HEART JOURNAL ONLINE', 'HEALTH POLICY PLANNING',
#        'HUMAN MOLECULAR GENETICS', 'INTERNATIONAL JOURNAL EPIDEMIOL',
#        'INTERNATIONALERNATIONAL JOURAL EPIDEMIOLOGY',
#        'INTERNATIONALERNATIONAL JOURNAL EPIDEMIOLOGY',
#        'JOURNAL ANTIMICROBIAL CHEMOTHERAPY', 'JOURNAL INFECTIOUS DISEASES',
#        'JOURNAL NATIONAL CANCER INSTITUTE', 'NUCLEIC ACIDS RESEARCH',
#        'PUBLIC HEALTH ETHICS', 'RHEUMATOLOGY', 'SCHIZOPHRENIA BULLETIN',
#        'SOCIAL COGNITIVE AND AFFECTIVE NEUROSCIENCE',
#        'CARDIOVASCULAR RESEARCH', 'CLINICAL INFECTIOUS DISEASE',
#        'GLYCOBIOLOGY', 'INTERNATIONAL JOURNAL EPIDEMIOLOGY',
#        'JOURNAL GERONTOLOGY SERIES A MEDICAL SCIENCES',
#        'JOURNAL PUBLIC HEALTH', 'MOLECULAR BIOLOGY AND EVOLUTION',
#        'NICOTINE AND TOBACO RESEARCH', 'SOCIAL HISTORY MEDICINE',
#        'BIOINFORMATICS ONLINE', 'CEREBRAL CORTEX PRINTERNATIONAL',
#        'HUMAN MOL GENETICS ONLINE', 'AGE AND AGEING', 'BIINFORMATICS',
#        'BIOINFORMATICS', 'BRAIN ONLINE', 'BRIEFINGS FUNCTIONAL GENOMICS',
#        'CEREBRAL CORTEX ONLINE', 'DATABASE',
#        'EUROPEAN JOURNAL PUBLIC HEALTH',
#        'HEALTH PROMOTION INTERNATIONALERNATIONAL',
#        'HISTORY WORKSHOP JOURNAL', 'HUMAN MOLECULAR GENETICS ONLINE',
#        'HUMAN REPRODUCTION', 'INTERNATIONALERNATIONAL IMMUNOLOGY',
#        'MEDICAL LAW REVIEW', 'MOLECULAR BIOLOGYL AND EVOLUTION',
#        'NEPHROLOGY DIALYSIS AND TRANSPLANTATION', 'OXFORD JOURNAL',
#        'OXFORD UNIVERSITY PRESS',
#        'PROTEIN ENGINEERING DESIGN AND SELECTION (',
#        'QJM AN INTERNATIONALERNATIONAL JOURNAL MEDICINE',
#        'ENVIRONMENT AND PLANNING A', 'PLOS COMPUTATIONAL BIOLOGY',
#        'PLOS GENETICS', 'PLOS NTD', 'PLOS ONE', 'PLOS PATHOGENS',
#        'JOURNAL POVERTY AND SOCIAL JUSTICE', 'ASN NEURO',
#        'BIOCHEMICAL JOURNAL', 'BIOCHEMICAL SOCIETY TRANSACTIONS',
#        'ESSAYS BIOCHEMISTRY', 'BIOCHEM SOC TRANS', 'BIOSCIENCE REPORTS',
#        'BIOLOGY', 'COMPUTATIONAL BIOLOGY', 'NEGLECTED TROPICAL DISEASE',
#        'PLOS BIOLOGY', 'PLOS MEDICINE', 'PLOS MEDICINE JOURNAL',
#        'PLOS NEGECTED TROPICAL DISEASES',
#        'PLOS NEGLECTED TROPICAL DISEASES', 'PMEDICINE-D-12-03130', 'PNTD',
#        'PONE-D12-17947', 'PUBLIC SERVICE REVIEW',
#        'J CARDIOVASC MAGN RESON', 'BRITISH JOURNAL PSYCHIATRY',
#        'BRITSH JOURNAL PSYCHIATRY', 'BIOLOGY LETTERS',
#        'INTERNATIONALERFACE', 'JOURNAL ROYAL SOCIETY INTERNATIONALERFACE',
#        'PHILOS TRANS R SOC LONDON B BIOL SCI',
#        'PHILOSOPHICAL TRANSACTIONS B', 'PROCEEDINGS B',
#        'PROCEEDINGS ROYAL SOCIETY',
#        'PROCEEDINGS ROYAL SOCIETY B BIOLOGICAL SCIENCES',
#        'CHEMICAL COMMUNICATION', 'CHEMICAL SOCIETY REVIEWS',
#        'DALTON TRANSACTIONS', 'PHOTOCHEMICAL AND PHOTOBIOLOGICAL SCIENCES',
#        'ORGANIC AND BIOMOLECULAR CHEMISTRY', 'CHRONIC ILLNESS',
#        'EUROPEAN JOURNAL PREVENTIVE CARDIOLOGY',
#        'HEALTH AN INTERNATIONALERDISCIPLINARY JOURNAL SOCIAL STUDY HEALTH ILLNESS AND MEDICINE',
#        'HISTORY HUMAN SCIENCES',
#        'JOURNAL HISTOCHEMISTRY AND CYTOCHEMISTRY', 'NEUROSCIENTIST',
#        'PSYCHOLOGICAL SCIENCE', 'SOCIAL STUDIES SCIENCE',
#        'JOURNAL PSYCHOPHARMACOLOGY', 'REPRODUCTIVE SCIENCES',
#        'JOURNAL ROYAL SOCIETY MEDICINE SHORT REPORTS',
#        'EUROPEAN HISTORY QUARTERLY', 'QUALITATIVE RESEARCH',
#        'INTERNATIONALERNATIONAL JOURNAL FINANCIAL RESEARCH',
#        'JOURNAL BIOMEDICAL GRAPHICS AND COMPUTING', 'HEALTH',
#        'AMERICAN JOURNAL TROPICAL MEDICINE AND HYGIENE',
#        'ENDOCRINE RELATED CANCER', 'JOURNAL GENERAL VIROLOGY',
#        'JOURNAL MICROBIOLOGY', 'SGM OPEN OPTION',
#        'ACTA DERMATO VENEREOLOGICA', 'ACTA DIABETOLOGICA',
#        'ACTA NEUROPATHOLOGICA',
#        'ADVANCES EXPERIMENTAL MEDICINE AND BIOLOGY', 'ANAL BIOANAL CHEM',
#        'BIOGERONTOLOGY', 'BIOMEDICAL MICRODEVICES',
#        'BRAIN STRUCTURE AND FUNCTION', 'BRAIN TOPOGRAPHY',
#        'CALCIFIED TISSUE INTERNATIONALERNATIONAL',
#        'CELL AND TISSUE RESEARCH', 'CELLULAR AND MOLECULAR CELL SCIENCES',
#        'CELLULAR AND MOLECULAR LIFE SCIENCES', 'CHROMOSOME RESEARCH',
#        'COGNITIVE PROCESSING', 'COGNITIVE THERAPY AND RESEARCH',
#        'CURRENT ATHEROSCLEROSIS REPORTS',
#        'CURRENT OBSTETRICS AND GYNECOLOGY REPORTS',
#        'DEVELOPMENT GENES AND EVOLUTION', 'DIABETOLOGIA',
#        'EUROPEAN CHILD AND ADOLESCENT PSYCHIATRY',
#        'EUROPEAN JOURNAL CLINICAL PHARMACOLOGY',
#        'EUROPEAN JOURNAL EPIDEMIOLOGY', 'EUROPEAN RADIOLOGY',
#        'EXPERIMENTAL BRAIN RESEARCH', 'HERNIA', 'IMMUNOGENETICS',
#        'INFLAMMATION RESEARCH',
#        'JOURNAL AUTISM AND DEVELOPMENTAL DISORDERS',
#        'JOURNAL BIOETHICAL INQUIRY', 'JOURNAL BIOLOGICAL PHYSICS',
#        'JOURNAL COMPUTATIONAL NEUROSCIENCE', 'JOURNAL INHERITED METABOLIC',
#        'JOURNAL MOLECULAR NEUROSCIENCE', 'JOURNAL NEUROLOGY',
#        'JOURNAL ASSOCIATION RESEARCH OTOLARYNGOLOGY', 'MAMMALIAN GENOME',
#        'METABOLOMICS', 'MOLECULAR AND CELLULAR BIOCHEMISTRY',
#        'NEUROGENETICS', 'NEUROINFORMATICS', 'NEUROMOLECULAR MEDICINE',
#        'OSTEOPOROSIS INTERNATIONALERNATIONAL', 'PFLUGERS ARCHIVE',
#        'PFLUGERS ARCHIVEE', 'PSYCHOPHARMACOLOGY',
#        'REPRODUCTIVE MEDICINE AND BIOLOGY', 'SEMINARS IMMUNOPATHOLOGY',
#        'SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOLOGYOGY',
#        'SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOLOGY', 'SPRINGER',
#        'JOURNAL ABNORMAL CHILD PSYCHOLOGY AND PSYCHIATRY',
#        'TROPICAL ANIMAL HEALTH AND PRODUCTION', 'UROLITHIASIS',
#        'AIDS BEHAV', 'OPEN CHOICE', 'SPRINGER SCIENCE + BUSINESS MEDIA',
#        'JOURNAL BIOENERGETICS AND BIOMEMBRANES', 'CHILDS NERV SYST', 'AGE',
#        'BIOMOLECULAR NMR ASSIGNMENTS', 'JOURNAL MOLECULAR MEDICINE',
#        'JOURNAL NEURAL TRANSMISSION',
#        'JOURNAL AMERICAN SOCIETY MASS SPECTROMETRY',
#        'AZANIA ARCHAEOLOGICAL RESEARCH AFRICA', 'AIDS CARE',
#        'ANNALS SCIENCE', 'CANADIAN JOURNAL AFRICAN STUDIES',
#        'CHILD NEUROPSYCHOLOGY', 'ENGLISH STUDIES',
#        'EUROPEAN JOURNAL ENGLISH STUDIES', 'JOURNAL CULTURAL ECONOMY',
#        'MEDICAL ANTHROPOLOGY', 'SCIENCE AS CULTURE', 'AM JOURNAL BIOETH',
#        'ETHN HEALTH', 'AMERICAN JOURNAL BIOETHICS--NEUROSCIENCE',
#        'SOUTH ASIAN HISTORY AND CULTURE', 'HISTORY FAMILY',
#        'JOURNAL EXPERIMENTAL NANOSCIENCE', 'JOURNAL APPLIED PHYSIOLOGY',
#        'PEDIATRICICS', 'JOURNAL CLINICAL ENDOCRINOLOGY',
#        'JOURNAL OD CLINICAL ENDOCRINOLOGY', 'BJP',
#        'PHILOSOPHICAL TRANSACTIONS ROYAL SOCIETY LONDON SERIES B BIOLOGICAL SCIENCES',
#        'RSTB 20120145', 'CANCER RESEARCH', 'SCIENCE-RESEARCH',
#        'AM JOURNAL TROP MED HYG', 'DEVELOPING WORLD BIOETHICS',
#        'INTERNATIONALERNATIONAL JOURNAL DEVELOPMENTAL BIOLOGY',
#        'ACTA PHYSIOL', 'ADDICTION', 'AGING CELL',
#        'ALIMENTRARY PHARMACOLOGY AND THERAPEUTICS', 'AMERICAN ETHNOLOGIST',
#        'AMERICAN JOURNAL MEDICAL GENETICS PART A', 'ANGEWANDE CHEMIE',
#        'ANGEWANDTE CHEMIE', 'ANNALS HUMAN GENETICS', 'ANNALS NEUROLOGY',
#        'ANNALS NEW YORK ACADEMY SCIENCES', 'ARTHRITIS AND RHEUMATISM',
#        'BIOETHICS',
#        'BIRTH DEFECTS RESEARCH PART A CLINICAL AND MOLECULAR TERATOLOGY',
#        'BRITISH JOURNAL CLINICAL PHARMACOLOGY',
#        'BRITISH JOURNAL DERMATOLOGY', 'BRITISH JOURNAL HAEMATOLOGY',
#        'BRITISH JOURNAL PHARMACOLOGY', 'CHEMBIOCHEM',
#        'CHEMISTRY EUROPEAN JOURNAL', 'CHILD PSYCHOLOGY PSYCHIATRY',
#        'CLINICAL GENETICS', 'CYTOSKELETON', 'DEVELOPMENT DYNAMICS',
#        'DEVELOPMENTAL SCIENCE', 'DIABETIC MEDICINE',
#        'ECOLOGY AND EVOLUTION', 'ECOLOGY LETTERS', 'EPILEPSIA',
#        'EUROPEAN JOURNAL NEUROSCIENCE', 'EVOLUTION',
#        'EXPERIMENTAL PHYSIOLOGY', 'FEBS JOURNAL',
#        'FEMS MICROBIOLOGY LETTERS', 'GENES BRAIN BEHAVIOR',
#        'GENESIS JOURNAL GENETICS', 'GLIA',
#        'HBM JOURNAL HUMAN BRAIN MAPPING', 'HIPPOCAMPUS',
#        'HUMAN BRAIN MAPPING', 'HUMAN MUTATION', 'IMMUNOLOGICAL REVIEWS',
#        'INFLAMMATORY BOWEL DISEASES',
#        'INTERNATIONALERNATIONAL JOURNAL GERIATRIC PSYCHIATRY',
#        'INTERNATIONALERNATIONAL JOURNAL STROKE',
#        'JOURNAL BONE AND MINERAL RESEARCH',
#        'JOURNAL CELLULAR BIOCHEMISTRY',
#        'JOURNAL CHILD PSYCHOLOGY AND PSYCHIATRY',
#        'JOURNAL EVOLUTIONARY BIOLOGY', 'JOURNAL NEUROCHEMISTRY',
#        'JOURNAL NEUROENDOCRINOLOGY', 'JOURNAL HISTORY BEHAVIORAL SCIENCES',
#        'JOURNAL ROYAL STATISTICAL SOCIETY SERIES C (APPLIED STATISTICS)',
#        'MAGNETIC RESONANCE MEDICINE', 'MOVEMENT DISORDERS',
#        'MUSCLE AND NERVE', 'NEUROPATHOLOGY AND APPLIED NEUROBIOLOGY',
#        'NMR BIOMEDICINE', 'PARASITE IMMUNOLOGY',
#        'PLANT BIOTECHNOLOGY JOURNAL', 'PROTEIN SCIENCE',
#        'RAPID COMMUNICATIONS MASS SPECTROMETRY',
#        'SOCIOLOGY HEALTH AND ILLNESS', 'STEM CELLS',
#        'CHILD CARE HEATH AND DEVELOPMENT', 'DRUG AND ALCOHOL REVIEW',
#        'EVOLUTIONARY APPLICATIONS',
#        'MOLECULAR GENETICS AND GENOMIC MEDICINE',
#        'MATERNAL AND CHILD NUTRITION', 'EVALUATION CLINICAL PRACTICE',
#        'JOURNAL CELL PHYSIOLOGY', 'JOURNAL INTERNATIONALERNAL MEDICINE',
#        'JOURNAL SLEEP RESEARCH', 'DEV WORLD BIOETH',
#        'INFLUENZA OTHER RESPI VIRUSES', 'TROP MED INTERNATIONAL HEALTH',
#        'CLINICAL TRANSCRIPTIONAL SCIENCE', 'IMMUNOLOGY',
#        'ACTA OPTHALMOLOGICA', 'AMERICAN JOURNAL TRANSPLANTATION',
#        'ANGEWANDTE CHEMIE INTERNATIONALERNATIONAL EDITION',
#        'BRITISH JOUNAL PHARMACOLOGY', 'CENTAURUS',
#        'CRIMINAL BEHAVIOR AND MENTAL HEALTH', 'DEPRESSION AND ANXIETY',
#        'DERMATOLOGIC SURGERY', 'ECONOMIC HISTORY REVIEW', 'HPB',
#        'INTERNATIONALERNATIONAL JOURNAL EXPERIMENTAL PATHOLOGY',
#        'JOURNAL COMPARATIVE NEUROLOGY',
#        'JOURNAL EVALUATION CLINICAL PRACTICE', 'JOURNAL MICROSCOPY',
#        'JOURNAL ORTHOPEDIC RESEARCH', 'JOURNAL VIRAL HEPATITIS',
#        'OBESITY REVIEWS', 'STATISTICS MEDICINE', 'SYNAPSE',
#        'ZOONOSES AND PUBLIC HEALTH', 'ANGEW CHEMS INTERNATIONAL ED',
#        'CHEMMEDCHEM', 'PROTEMICS', 'JOURNAL SMALL ANIMAL PRACTICE',
#        'AIDS JOURNAL', 'JOURNAL ACQUIRED IMMUNE DEFICIENCY SYNDROMES',
#        'CIRCULATION RESEARCH', 'PEDIATRIC INFECT DIS J'], dtype=object)

# %%
df.describe()
# Out:
#           ID Publisher   Journal  \
# count   1928      2126      2126
# unique  1880       298       984
# top        -  Elsevier  PLoS One
# freq       7       387        92
#
#                                                   Article      Cost  \
# count                                                2126      2126
# unique                                               2125      1401
# top     Exclusive breastfeeding, diarrhoel morbidity a...  £2040.00
# freq                                                    2        94
#
#        clean_journal
# count           2126
# unique           779
# top         PLOS ONE
# freq             213

# %%
df1 = df.groupby('clean_journal').count()
df1
# Out:
#                                                     ID  Publisher  Journal  \
# clean_journal
# ACADEMY NUTRITION AND DIETETICS                      1          1        1
# ACS CHEMICAL BIOLOGY                                 4          5        5
# ACS CHEMICAL NEUROSCIENCE                            1          1        1
# ACS NANO                                             2          2        2
# ACTA D                                               5          5        5
# ACTA DERMATO VENEREOLOGICA                           1          1        1
# ACTA DIABETOLOGICA                                   1          1        1
# ACTA F                                               3          3        3
# ACTA NEUROPATHOLOGICA                                3          4        4
# ACTA OPTHALMOLOGICA                                  1          1        1
# ACTA PHYSIOL                                         1          1        1
# ADDICTION                                            2          2        2
# ADVANCES EXPERIMENTAL MEDICINE AND BIOLOGY           0          4        4
# AGE                                                  2          2        2
# AGE AND AGEING                                       1          1        1
# AGEING AND SOCIETY                                   0          1        1
# AGING CELL                                           1          1        1
# AIDS BEHAV                                           1          1        1
# AIDS CARE                                            4          4        4
# AIDS JOURNAL                                         6          6        6
# AIDS RESEARCH AND THERAPY                            1          1        1
# ALCOHOL AND ALCOHOLISM                               1          1        1
# ALIMENTRARY PHARMACOLOGY AND THERAPEUTICS            2          2        2
# AM JOURNAL BIOETH                                    1          1        1
# AM JOURNAL TROP MED HYG                              1          1        1
# AMERICAN CHEMICAL SOCIETY                            1          1        1
# AMERICAN ETHNOLOGIST                                 0          2        2
# AMERICAN JOURNAL BIOETHICS--NEUROSCIENCE             1          1        1
# AMERICAN JOURNAL CLINICAL NUTRITION                  2          2        2
# AMERICAN JOURNAL EPIDEMIOLOGY                        4          4        4
# ...                                                 ..        ...      ...
# TISSUE ENGINEERING PART A                            1          1        1
# TRAFFIC                                              5          6        6
# TRANSACTIONS ROYAL SOCIETY TROPICAL MEDICINE AN...   1          1        1
# TRANSLATIONAL PSYCHIATRY                             2          2        2
# TRENDS COGNITIVE SCIENCE                             1          1        1
# TRENDS GENETICS                                      2          2        2
# TRENDS MICROBIOLOGY                                  1          1        1
# TRENDS MOLECULAR MEDICINE                            1          1        1
# TRENDS NEUROSCIENCES                                 1          1        1
# TRENDS NEUROSCIENCESS                                1          2        2
# TRENDS PARASITOLOGY                                  0          4        4
# TRIALS                                               5          5        5
# TROP MED INTERNATIONAL HEALTH                        1          1        1
# TROPICAL ANIMAL HEALTH AND PRODUCTION                1          1        1
# TROPICAL MEDICINE AND INTERNATIONALERNATIONAL H...   5          6        6
# TUBERCULOSIS                                         2          2        2
# URBAN HISTORY                                        0          1        1
# UROLITHIASIS                                         1          1        1
# VACCINE                                              5          5        5
# VASCULAR PHARMACOLOGY                                1          1        1
# VET JOURNAL                                          1          1        1
# VETERINARY MICROBIOLOGY                              1          1        1
# VETERINARY PARASITOLOGY                              1          2        2
# VETERINARY RECORD                                    1          1        1
# VETERINARY RESEARCH                                  1          1        1
# VIROLOGY JOURNAL                                     1          1        1
# VIRUS RESEARCH                                       1          1        1
# VISION RESEARCH                                      2          2        2
# VISUAL NEUROSCIENCE                                  1          1        1
# ZOONOSES AND PUBLIC HEALTH                           1          1        1
#
#                                                     Article  Cost
# clean_journal
# ACADEMY NUTRITION AND DIETETICS                           1     1
# ACS CHEMICAL BIOLOGY                                      5     5
# ACS CHEMICAL NEUROSCIENCE                                 1     1
# ACS NANO                                                  2     2
# ACTA D                                                    5     5
# ACTA DERMATO VENEREOLOGICA                                1     1
# ACTA DIABETOLOGICA                                        1     1
# ACTA F                                                    3     3
# ACTA NEUROPATHOLOGICA                                     4     4
# ACTA OPTHALMOLOGICA                                       1     1
# ACTA PHYSIOL                                              1     1
# ADDICTION                                                 2     2
# ADVANCES EXPERIMENTAL MEDICINE AND BIOLOGY                4     4
# AGE                                                       2     2
# AGE AND AGEING                                            1     1
# AGEING AND SOCIETY                                        1     1
# AGING CELL                                                1     1
# AIDS BEHAV                                                1     1
# AIDS CARE                                                 4     4
# AIDS JOURNAL                                              6     6
# AIDS RESEARCH AND THERAPY                                 1     1
# ALCOHOL AND ALCOHOLISM                                    1     1
# ALIMENTRARY PHARMACOLOGY AND THERAPEUTICS                 2     2
# AM JOURNAL BIOETH                                         1     1
# AM JOURNAL TROP MED HYG                                   1     1
# AMERICAN CHEMICAL SOCIETY                                 1     1
# AMERICAN ETHNOLOGIST                                      2     2
# AMERICAN JOURNAL BIOETHICS--NEUROSCIENCE                  1     1
# AMERICAN JOURNAL CLINICAL NUTRITION                       2     2
# AMERICAN JOURNAL EPIDEMIOLOGY                             4     4
# ...                                                     ...   ...
# TISSUE ENGINEERING PART A                                 1     1
# TRAFFIC                                                   6     6
# TRANSACTIONS ROYAL SOCIETY TROPICAL MEDICINE AN...        1     1
# TRANSLATIONAL PSYCHIATRY                                  2     2
# TRENDS COGNITIVE SCIENCE                                  1     1
# TRENDS GENETICS                                           2     2
# TRENDS MICROBIOLOGY                                       1     1
# TRENDS MOLECULAR MEDICINE                                 1     1
# TRENDS NEUROSCIENCES                                      1     1
# TRENDS NEUROSCIENCESS                                     2     2
# TRENDS PARASITOLOGY                                       4     4
# TRIALS                                                    5     5
# TROP MED INTERNATIONAL HEALTH                             1     1
# TROPICAL ANIMAL HEALTH AND PRODUCTION                     1     1
# TROPICAL MEDICINE AND INTERNATIONALERNATIONAL H...        6     6
# TUBERCULOSIS                                              2     2
# URBAN HISTORY                                             1     1
# UROLITHIASIS                                              1     1
# VACCINE                                                   5     5
# VASCULAR PHARMACOLOGY                                     1     1
# VET JOURNAL                                               1     1
# VETERINARY MICROBIOLOGY                                   1     1
# VETERINARY PARASITOLOGY                                   2     2
# VETERINARY RECORD                                         1     1
# VETERINARY RESEARCH                                       1     1
# VIROLOGY JOURNAL                                          1     1
# VIRUS RESEARCH                                            1     1
# VISION RESEARCH                                           2     2
# VISUAL NEUROSCIENCE                                       1     1
# ZOONOSES AND PUBLIC HEALTH                                1     1
#
# [779 rows x 5 columns]

# %%
df['clean_journal'].value_counts().head(5)
# Out:
# PLOS ONE                                 213
# JOURNAL BIOLOGICAL CHEMISTRY              65
# PROCEEDINGS NATIONAL ACADEMY SCIENCES     37
# NEUROIMAGE                                31
# NUCLEIC ACIDS RESEARCH                    29
# Name: clean_journal, dtype: int64

# %% [markdown]
# These are the five most common journals. I will now calculate the total articles for each.

# %%
df1.sort_values('Article', ascending=False).head(5)
# Out:
#                                         ID  Publisher  Journal  Article  Cost
# clean_journal
# PLOS ONE                               203        213      213      213   213
# JOURNAL BIOLOGICAL CHEMISTRY            64         65       65       65    65
# PROCEEDINGS NATIONAL ACADEMY SCIENCES   37         37       37       37    37
# NEUROIMAGE                              30         31       31       31    31
# NUCLEIC ACIDS RESEARCH                  28         29       29       29    29

# %% [markdown]
# These are the five most common journals and their total articles. Next, I will calculate the mean, median and standard deviation of the open-access cost per article for each journal.

# %%
df['Cost'] = df['Cost'].str.lstrip('£').str.rstrip('$').astype(float)

# %% [markdown]
# These are the five most common journals and their total articles. Next, I will calculate the mean, median and standard deviation of the open-access cost per article for each journal.

# %%
df.Cost.describe()
# Out:
# count      2126.000000
# mean      24072.451609
# std      146895.027687
# min           0.000000
# 25%        1280.000000
# 50%        1883.860000
# 75%        2321.230000
# max      999999.000000
# Name: Cost, dtype: float64

# %% [markdown]
# The mean, median and standard deviation for all cost per articles are 24072.45, 1883.86, and 146895.03 respectively. Next, I will calcualate the mean, median and standard deviation for each of our top five journals.

# %%
plos = df.loc[df['clean_journal'] == 'PLOS ONE']
j_biochem = df.loc[df['clean_journal'] == 'JOURNAL BIOLOGICAL CHEMISTRY']
proc_nas = df.loc[df['clean_journal'] == 'PROCEEDINGS NATIONAL ACADEMY SCIENCES']
neuroimage = df.loc[df['clean_journal'] == 'NEUROIMAGE']
nuc_acids = df.loc[df['clean_journal'] == 'NUCLEIC ACIDS RESEARCH']

# %%
plos.Cost.describe()
# Out:
# count       213.000000
# mean      39361.418357
# std      190670.090657
# min         122.310000
# 25%         852.950000
# 50%         902.120000
# 75%        1044.740000
# max      999999.000000
# Name: Cost, dtype: float64

# %%
j_biochem.Cost.describe()
# Out:
# count        65.000000
# mean      32106.840154
# std      173795.906174
# min         265.670000
# 25%        1150.600000
# 50%        1311.730000
# 75%        1600.250000
# max      999999.000000
# Name: Cost, dtype: float64

# %%
proc_nas.Cost.describe()
# Out:
# count        37.000000
# mean      27779.029459
# std      164272.161311
# min         206.320000
# 25%         625.000000
# 50%         732.250000
# 75%         793.020000
# max      999999.000000
# Name: Cost, dtype: float64

# %%
neuroimage.Cost.describe()
# Out:
# count      31.000000
# mean     2212.181290
# std       273.193244
# min      1747.160000
# 25%      2030.895000
# 50%      2326.430000
# 75%      2408.680000
# max      2518.230000
# Name: Cost, dtype: float64

# %%
nuc_acids.Cost.describe()
# Out:
# count      29.000000
# mean     1162.344828
# std       442.150934
# min       710.000000
# 25%       852.000000
# 50%       852.000000
# 75%      1704.000000
# max      2184.000000
# Name: Cost, dtype: float64
